# %% [markdown]
# # Experiments with I/O -> trace and trace -> code model run consecutively.
#
# ## I/O -> trace
# `python train.py
# --dataset karel
# --karel-train-shuf
# --karel-trace-inc-val
# --model_type karel-trace-pred
# --karel-trace-grid-enc presnet
# --debug_every_n=1000 --eval_every_n=2000 --keep_every_n=10000 --log_interval=100
# --batch_size 64 --num_epochs 50 --max_beam_trees 1 --optimizer sgd --gradient-clip 1 --lr 1 --lr_decay_steps 100000 --lr_decay_rate 0.5
# --model_dir ../logdirs/20180321/karel-trace-pred-gridpresnet`
#
# Snapshot from iteration 250000 was used, with beam size 1:
# `python infer.py --model_type karel-trace-pred --dataset karel-00${i}-of-008 --karel-trace-inc-val --eval-train --max_beam_trees 1 --model_dir ../logdirs/20180321/karel-trace-pred-gridpresnet --step 250100 --max_decoder_length 1000 --infer-output ../data/karel/train-20180321-trace-pred-gridpresnet-bs1-st250100-00${i}-of-008.pkl`
#
# ## Trace -> code
# Concatenate action and each timestep in trace, no grids in trace:
# `python train.py --dataset karel-20180222-trace-pred-gridpresnet-bs1-st250100 --model_type karel-code-trace --karel-train-shuf --batch-create-train 'ConstantBatch(5, 1, True)' --karel-io-enc lgrl --karel-trace-action-enc emb --karel-trace-grid-enc none --karel-trace-cond-enc concat --karel-trace-enc indiv:concat --num_placeholders 0 --debug_every_n=1000 --eval_every_n=2000 --keep_every_n=10000 --log_interval=100 --batch_size 64 --num_epochs 50  --max_beam_trees 1 --optimizer sgd --gradient-clip 1 --lr 1 --lr_decay_steps 100000 --lr_decay_rate 0.5 --model_dir ../logdirs/20180321/karel-code-trace-ioshuf-concat-nogrid`
#
# Interleave actions and trace, no grids:
# `python train.py --dataset karel-20180222-trace-pred-gridpresnet-bs1-st250100 --model_type karel-code-trace --karel-train-shuf --batch-create-train 'ConstantBatch(5, 1, True)' --karel-io-enc lgrl --karel-trace-action-enc emb --karel-trace-grid-enc none --karel-trace-cond-enc concat --karel-trace-enc indiv:interleave --num_placeholders 0 --debug_every_n=1000 --eval_every_n=2000 --keep_every_n=10000 --log_interval=100 --batch_size 64 --num_epochs 50  --max_beam_trees 1 --optimizer sgd --gradient-clip 1 --lr 1 --lr_decay_steps 100000 --lr_decay_rate 0.5 --model_dir ../logdirs/20180321/karel-code-trace-ioshuf-interleave-nogrid`
#
# **Best top-1 number**: 0.8148

# %%
import collections
import glob
import json
import re

import pandas as pd

# %%
rows = []
for path in glob.glob('../logdirs/20180321/karel-code-trace*/report*'):
    trace_type = re.search('(concat|interleave)', path).group(1)
    grid = '-nogrid' not in path
    io = '-noio' not in path
    actions = '-noactions' not in path
    
    bs = int(re.search(r'-bs(\d+)-', path).group(1))
    step = re.search(r'(\d+)\.jsonl', path).group(1)
    
    results = json.load(open(path))
    row = [trace_type, grid, io, actions, bs, step]
    for k in (0, 4, 42):
        if k >= bs:
            row.extend([0, 0, 0])
            continue
        row.append(results['exact'][k] / results['total'])
        row.append(results['semantic'][k] / results['total'])
        row.append(results['generalization'][k] / results['total'])
    rows.append(row)
    
columns = ['trace_type', 'grid', 'io', 'actions', 'bs', 'step']
for k in (0, 4, 42):
    columns.extend(x.format(k+1) for x in ('top{}-exact', 'top{}-sem', 'top{}-gen'))

# %%
results = pd.DataFrame(rows, columns=columns)

# %%
results.sort_values(by='top1-gen')
# Out:
#     trace_type   grid    io  actions  bs    step  top1-exact  top1-sem  \
# 48      concat  False  True     True   1   50100      0.3964    0.7568
# 15  interleave  False  True     True   1   50100      0.4044    0.7668
# 51      concat  False  True     True   1  750100      0.4052    0.7896
# 43      concat  False  True     True   1  872500      0.4048    0.7908
# 52      concat  False  True     True   1  800100      0.4048    0.7916
# 22      concat  False  True     True   1  850100      0.4048    0.7916
# 28      concat  False  True     True   1  700100      0.4040    0.7920
# 39      concat  False  True     True   1  650100      0.4064    0.7936
# 9   interleave  False  True     True   1  150100      0.4108    0.7948
# 6   interleave  False  True     True   1  100100      0.4060    0.7964
# 26      concat  False  True     True   1  550100      0.4084    0.7984
# 36      concat  False  True     True   1  100100      0.4108    0.7944
# 27      concat  False  True     True   1  600100      0.4072    0.7972
# 29      concat  False  True     True   1  300100      0.4144    0.8000
# 19      concat  False  True     True   1  450100      0.4096    0.8028
# 21      concat  False  True     True   1  500100      0.4104    0.8032
# 50      concat  False  True     True  43   50100      0.4164    0.7952
# 40      concat  False  True     True   1  150100      0.4104    0.8040
# 11  interleave  False  True     True   1  250100      0.4112    0.8080
# 12  interleave  False  True     True   1  350100      0.4124    0.8072
# 41      concat  False  True     True   1  400100      0.4104    0.8096
# 44      concat  False  True     True   1  250100      0.4152    0.8068
# 45      concat  False  True     True   1  350100      0.4172    0.8076
# 23      concat  False  True     True   1  200100      0.4092    0.8092
# 2   interleave  False  True     True   1  300100      0.4120    0.8104
# 10  interleave  False  True     True   1  400100      0.4108    0.8092
# 0   interleave  False  True     True   1  200100      0.4104    0.8124
# 17  interleave  False  True     True  43   50100      0.4156    0.8052
# 8   interleave  False  True     True   1  433500      0.4112    0.8088
# 30      concat  False  True     True  43  100100      0.4236    0.8240
# 3   interleave  False  True     True  43  100100      0.4224    0.8296
# 31      concat  False  True     True  43  150100      0.4252    0.8336
# 25      concat  False  True     True  43  800100      0.4224    0.8360
# 42      concat  False  True     True  43  850100      0.4200    0.8380
# 35      concat  False  True     True  43  700100      0.4220    0.8372
# 20      concat  False  True     True  43  872500      0.4216    0.8376
# 47      concat  False  True     True  43  600100      0.4240    0.8376
# 18      concat  False  True     True  43  650100      0.4240    0.8376
# 33      concat  False  True     True  43  750100      0.4224    0.8384
# 37      concat  False  True     True  43  500100      0.4252    0.8404
# 32      concat  False  True     True  43  450100      0.4276    0.8408
# 4   interleave  False  True     True  43  150100      0.4280    0.8388
# 53      concat  False  True     True  43  550100      0.4244    0.8408
# 49      concat  False  True     True  43  300100      0.4316    0.8404
# 24      concat  False  True     True  43  400100      0.4256    0.8412
# 46      concat  False  True     True  43  350100      0.4280    0.8436
# 38      concat  False  True     True  43  200100      0.4292    0.8424
# 34      concat  False  True     True  43  250100      0.4324    0.8436
# 7   interleave  False  True     True  43  200100      0.4268    0.8460
# 14  interleave  False  True     True  43  350100      0.4248    0.8508
# 1   interleave  False  True     True  43  400100      0.4240    0.8516
# 5   interleave  False  True     True  43  250100      0.4256    0.8516
# 13  interleave  False  True     True  43  433500      0.4236    0.8532
# 16  interleave  False  True     True  43  300100      0.4276    0.8564
#
#     top1-gen  top5-exact  top5-sem  top5-gen  top43-exact  top43-sem  \
# 48    0.7232      0.0000    0.0000    0.0000       0.0000     0.0000
# 15    0.7304      0.0000    0.0000    0.0000       0.0000     0.0000
# 51    0.7516      0.0000    0.0000    0.0000       0.0000     0.0000
# 43    0.7520      0.0000    0.0000    0.0000       0.0000     0.0000
# 52    0.7532      0.0000    0.0000    0.0000       0.0000     0.0000
# 22    0.7536      0.0000    0.0000    0.0000       0.0000     0.0000
# 28    0.7536      0.0000    0.0000    0.0000       0.0000     0.0000
# 39    0.7552      0.0000    0.0000    0.0000       0.0000     0.0000
# 9     0.7564      0.0000    0.0000    0.0000       0.0000     0.0000
# 6     0.7576      0.0000    0.0000    0.0000       0.0000     0.0000
# 26    0.7580      0.0000    0.0000    0.0000       0.0000     0.0000
# 36    0.7596      0.0000    0.0000    0.0000       0.0000     0.0000
# 27    0.7608      0.0000    0.0000    0.0000       0.0000     0.0000
# 29    0.7620      0.0000    0.0000    0.0000       0.0000     0.0000
# 19    0.7624      0.0000    0.0000    0.0000       0.0000     0.0000
# 21    0.7628      0.0000    0.0000    0.0000       0.0000     0.0000
# 50    0.7636      0.5156    0.8572    0.8260       0.5832     0.9012
# 40    0.7652      0.0000    0.0000    0.0000       0.0000     0.0000
# 11    0.7668      0.0000    0.0000    0.0000       0.0000     0.0000
# 12    0.7668      0.0000    0.0000    0.0000       0.0000     0.0000
# 41    0.7680      0.0000    0.0000    0.0000       0.0000     0.0000
# 44    0.7684      0.0000    0.0000    0.0000       0.0000     0.0000
# 45    0.7688      0.0000    0.0000    0.0000       0.0000     0.0000
# 23    0.7688      0.0000    0.0000    0.0000       0.0000     0.0000
# 2     0.7696      0.0000    0.0000    0.0000       0.0000     0.0000
# 10    0.7700      0.0000    0.0000    0.0000       0.0000     0.0000
# 0     0.7712      0.0000    0.0000    0.0000       0.0000     0.0000
# 17    0.7712      0.5168    0.8620    0.8308       0.5816     0.9044
# 8     0.7716      0.0000    0.0000    0.0000       0.0000     0.0000
# 30    0.7892      0.5308    0.8780    0.8468       0.5980     0.9156
# 3     0.7920      0.5252    0.8828    0.8480       0.5976     0.9200
# 31    0.7948      0.5296    0.8848    0.8524       0.5964     0.9192
# 25    0.7964      0.5232    0.8868    0.8516       0.5892     0.9180
# 42    0.7980      0.5232    0.8860    0.8508       0.5868     0.9176
# 35    0.7980      0.5240    0.8868    0.8504       0.5904     0.9176
# 20    0.7980      0.5224    0.8864    0.8512       0.5872     0.9180
# 47    0.7984      0.5292    0.8888    0.8540       0.5920     0.9192
# 18    0.7988      0.5244    0.8864    0.8524       0.5912     0.9176
# 33    0.7988      0.5228    0.8860    0.8500       0.5884     0.9184
# 37    0.7996      0.5312    0.8896    0.8524       0.5940     0.9200
# 32    0.8004      0.5344    0.8920    0.8576       0.5944     0.9220
# 4     0.8004      0.5328    0.8868    0.8512       0.6080     0.9208
# 53    0.8008      0.5292    0.8896    0.8544       0.5908     0.9204
# 49    0.8016      0.5348    0.8924    0.8556       0.5992     0.9188
# 24    0.8016      0.5308    0.8928    0.8552       0.5944     0.9212
# 46    0.8032      0.5360    0.8908    0.8560       0.5984     0.9232
# 38    0.8040      0.5308    0.8856    0.8536       0.6020     0.9236
# 34    0.8044      0.5340    0.8916    0.8556       0.6008     0.9248
# 7     0.8072      0.5312    0.8892    0.8544       0.6084     0.9232
# 14    0.8096      0.5332    0.8936    0.8616       0.6068     0.9212
# 1     0.8100      0.5348    0.8912    0.8580       0.6068     0.9192
# 5     0.8112      0.5344    0.8924    0.8584       0.6072     0.9220
# 13    0.8136      0.5316    0.8924    0.8588       0.6044     0.9200
# 16    0.8148      0.5344    0.8944    0.8604       0.6040     0.9252
#
#     top43-gen
# 48     0.0000
# 15     0.0000
# 51     0.0000
# 43     0.0000
# 52     0.0000
# 22     0.0000
# 28     0.0000
# 39     0.0000
# 9      0.0000
# 6      0.0000
# 26     0.0000
# 36     0.0000
# 27     0.0000
# 29     0.0000
# 19     0.0000
# 21     0.0000
# 50     0.8732
# 40     0.0000
# 11     0.0000
# 12     0.0000
# 41     0.0000
# 44     0.0000
# 45     0.0000
# 23     0.0000
# 2      0.0000
# 10     0.0000
# 0      0.0000
# 17     0.8768
# 8      0.0000
# 30     0.8896
# 3      0.8892
# 31     0.8904
# 25     0.8868
# 42     0.8868
# 35     0.8864
# 20     0.8872
# 47     0.8892
# 18     0.8888
# 33     0.8872
# 37     0.8904
# 32     0.8940
# 4      0.8908
# 53     0.8924
# 49     0.8928
# 24     0.8904
# 46     0.8964
# 38     0.8952
# 34     0.8952
# 7      0.8936
# 14     0.8932
# 1      0.8916
# 5      0.8912
# 13     0.8912
# 16     0.8936

# %%
results.groupby(['trace_type', 'bs']).agg({'top1-gen': 'max', 'step': 'first'})
# Out:
#                  step  top1-gen
# trace_type bs
# concat     1   450100    0.7688
#            43  650100    0.8044
# interleave 1   200100    0.7716
#            43  400100    0.8148

# %%
results.groupby(['trace_type', 'bs']).agg({'top43-gen': 'max', 'step': 'first'})
# Out:
#                  step  top43-gen
# trace_type bs
# concat     1   450100     0.0000
#            43  650100     0.8964
# interleave 1   200100     0.0000
#            43  400100     0.8936
